# %%
import pandas as pd
data=pd.read_csv("/home/placement/Downloads/fiat500.csv")
print(data)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %% [markdown]
# # loc[]

# %%
data1=data.loc[(data.km<=50000)]

# %%
data1
# Out:
#         ID   model  engine_power  age_in_days     km  previous_owners  \
# 0        1  lounge            51          882  25000                1
# 1        2     pop            51         1186  32500                1
# 6        7  lounge            51          731  11600                1
# 7        8  lounge            51         1521  49076                1
# 10      11     pop            51          790  43286                1
# ...    ...     ...           ...          ...    ...              ...
# 1525  1526  lounge            51          790  41870                1
# 1526  1527  lounge            51         1705  23600                1
# 1527  1528     pop            51          517   3000                1
# 1529  1530  lounge            51          731  22551                1
# 1530  1531  lounge            51          670  29000                1
#
#             lat       lon  price
# 0     44.907242   8.61156   8900
# 1     45.666359  12.24189   8800
# ...

# %% [markdown]
# # groupby()

# %%
data2=data1.groupby(["model"]).count()

# %%
data2
# Out:
#          ID  engine_power  age_in_days   km  previous_owners  lat  lon  price
# model
# lounge  734           734          734  734              734  734  734    734
# pop     162           162          162  162              162  162  162    162
# sport    11            11           11   11               11   11   11     11

# %% [markdown]
# # rename the column

# %%
data3=data.rename(columns={'model':'model_name'})

# %%
list(data3)
# Out:
# ['ID',
#  'model_name',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %% [markdown]
# # drop the column

# %%
data3.drop(columns='lon')
# Out:
#         ID model_name  engine_power  age_in_days      km  previous_owners  \
# 0        1     lounge            51          882   25000                1
# 1        2        pop            51         1186   32500                1
# 2        3      sport            74         4658  142228                1
# 3        4     lounge            51         2739  160000                1
# 4        5        pop            73         3074  106880                1
# ...    ...        ...           ...          ...     ...              ...
# 1533  1534      sport            51         3712  115280                1
# 1534  1535     lounge            74         3835  112000                1
# 1535  1536        pop            51         2223   60457                1
# 1536  1537     lounge            51         2557   80750                1
# 1537  1538        pop            51         1766   54276                1
#
#             lat  price
# 0     44.907242   8900
# 1     45.666359   8800
# ...

# %%
data3
# Out:
#         ID model_name  engine_power  age_in_days      km  previous_owners  \
# 0        1     lounge            51          882   25000                1
# 1        2        pop            51         1186   32500                1
# 2        3      sport            74         4658  142228                1
# 3        4     lounge            51         2739  160000                1
# 4        5        pop            73         3074  106880                1
# ...    ...        ...           ...          ...     ...              ...
# 1533  1534      sport            51         3712  115280                1
# 1534  1535     lounge            74         3835  112000                1
# 1535  1536        pop            51         2223   60457                1
# 1536  1537     lounge            51         2557   80750                1
# 1537  1538        pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# ...

# %%
data4=data3.drop(columns='lat')#drop the 'lat' column

# %%
data4
# Out:
#         ID model_name  engine_power  age_in_days      km  previous_owners  \
# 0        1     lounge            51          882   25000                1
# 1        2        pop            51         1186   32500                1
# 2        3      sport            74         4658  142228                1
# 3        4     lounge            51         2739  160000                1
# 4        5        pop            73         3074  106880                1
# ...    ...        ...           ...          ...     ...              ...
# 1533  1534      sport            51         3712  115280                1
# 1534  1535     lounge            74         3835  112000                1
# 1535  1536        pop            51         2223   60457                1
# 1536  1537     lounge            51         2557   80750                1
# 1537  1538        pop            51         1766   54276                1
#
#             lon  price
# 0      8.611560   8900
# 1     12.241890   8800
# ...

# %%
data.groupby(['model']).count()  #count the each model using groupby function
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
data.sample(5)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 821    822  lounge            51         1127   37000                1
# 807    808  lounge            51          701   19000                1
# 1395  1396  lounge            51          456   20941                1
# 1121  1122  lounge            51         1035   25000                1
# 928    929     pop            51         4627  148000                1
#
#             lat        lon  price
# 821   40.672379  14.728220  10500
# 807   40.672379  14.728220   9999
# 1395  39.291222  16.252514   9700
# 1121  41.055920  14.299440   9500
# 928   45.356602   9.203450   3500

# %%
data1=data.drop(columns=['model'])

# %%
data1
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 1        2            51         1186   32500                1  45.666359
# 2        3            74         4658  142228                1  45.503300
# 3        4            51         2739  160000                1  40.633171
# 4        5            73         3074  106880                1  41.903221
# ...    ...           ...          ...     ...              ...        ...
# 1533  1534            51         3712  115280                1  45.069679
# 1534  1535            74         3835  112000                1  45.845692
# 1535  1536            51         2223   60457                1  45.481541
# 1536  1537            51         2557   80750                1  45.000702
# 1537  1538            51         1766   54276                1  40.323410
#
#             lon  price
# 0      8.611560   8900
# 1     12.241890   8800
# ...

# %% [markdown]
# # correlation and Heatmap

# %%
cor=data1.corr()

# %%
cor
# Out:
#                        ID  engine_power  age_in_days        km  \
# ID               1.000000     -0.034059    -0.060753 -0.006537
# engine_power    -0.034059      1.000000     0.319190  0.285495
# age_in_days     -0.060753      0.319190     1.000000  0.833890
# km              -0.006537      0.285495     0.833890  1.000000
# previous_owners  0.007803     -0.005030     0.075775  0.097539
# lat             -0.058207      0.005721     0.062982  0.035519
# lon              0.058941     -0.005032    -0.042667  0.004839
# price            0.028516     -0.277235    -0.893328 -0.859373
#
#                  previous_owners       lat       lon     price
# ID                      0.007803 -0.058207  0.058941  0.028516
# engine_power           -0.005030  0.005721 -0.005032 -0.277235
# age_in_days             0.075775  0.062982 -0.042667 -0.893328
# km                      0.097539  0.035519  0.004839 -0.859373
# previous_owners         1.000000  0.001697 -0.026836 -0.076274
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=5,cmap='bwr')
# Out:
# <Axes: >
